# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import RFE
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.ensemble import RandomForestClassifier
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.linear_model import Ridge
import seaborn as sns
sns.set()
import joblib
from sklearn.dummy import DummyClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import confusion_matrix
from sklearn.naive_bayes import GaussianNB
from scipy.stats import uniform,randint
from tqdm import tqdm
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import AdaBoostClassifier
import pickle
import sklearn.preprocessing as preproc 
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %%
import math
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.layers import Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.losses import MeanSquaredLogarithmicError

# %%
df = pd.read_csv('EDA_dataset.csv')

# %%
df.info
# Out:
# <bound method DataFrame.info of                      Country_Name  Year  \
# 0     Africa Eastern and Southern  1999
# 1     Africa Eastern and Southern  2000
# 2     Africa Eastern and Southern  2001
# 3     Africa Eastern and Southern  2002
# 4     Africa Eastern and Southern  2003
# ...                           ...   ...
# 1161                     Zimbabwe  2016
# 1162                     Zimbabwe  2017
# 1163                     Zimbabwe  2018
# 1164                     Zimbabwe  2019
# 1165                     Zimbabwe  2020
#
#       Access_to_electricity_(%_of_population)  \
# 0                                2.359690e+11
# 1                                1.995793e+01
# 2                                1.998622e+01
# 3                                2.160150e+01
# 4                                2.254831e+01
# ...                                       ...
# 1161                             4.256173e+01
# 1162                             4.417863e+01
# 1163                             4.557265e+01
# 1164                             4.678148e+01
# 1165                             5.274767e+01
#
#       Adjusted_net_enrollment_rate,_primary_(%_of_primary_school_age_children)  \
# 0                                          2.359690e+11
# 1                                          2.270450e+11
# 2                                          2.460002e+11
# 3                                          2.489774e+11
# 4                                          2.652209e+11
# ...                                                 ...
# 1161                                       5.490718e+11
# 1162                                       5.527886e+11
# 1163                                       5.726864e+11
# 1164                                       6.642367e+11
# 1165                                       7.302537e+11
#
#       Adjusted_net_national_income_(constant_2015_US$)  \
# 0                                         2.359690e+11
# 1                                         2.270450e+11
# 2                                         2.460002e+11
# 3                                         3.991570e+11
# 4                                         4.191230e+11
# ...                                                ...
# 1161                                      1.716261e+10
# 1162                                      1.776074e+10
# 1163                                      1.026982e+10
# 1164                                      1.594563e+10
# 1165                                      1.337349e+10
#
#       Adjusted_net_national_income_per_capita_(annual_%_growth)  \
# 0                                          2.359690e+11
# 1                                          2.270450e+11
# 2                                          2.460002e+11
# 3                                          2.489774e+11
# 4                                          2.323504e+00
# ...                                                 ...
# 1161                                      -2.684791e+00
# 1162                                       1.391659e+00
# 1163                                      -4.333347e+01
# 1164                                       5.220881e+01
# 1165                                      -1.781697e+01
#
#       Adjusted_net_national_income_per_capita_(constant_2015_US$)  \
# 0                                          2.359690e+11
# 1                                          2.270450e+11
# 2                                          2.460002e+11
# 3                                          9.442113e+02
# 4                                          9.661501e+02
# ...                                                 ...
# 1161                                       1.187502e+03
# 1162                                       1.204028e+03
# 1163                                       6.822808e+02
# 1164                                       1.038492e+03
# 1165                                       8.534638e+02
#
#       Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_bottom_40%_of_population_(%)  \
# 0                                          2.359690e+11
# 1                                          2.270450e+11
# 2                                          2.460002e+11
# 3                                          2.489774e+11
# 4                                          2.652209e+11
# ...                                                 ...
# 1161                                       5.490718e+11
# 1162                                      -3.750000e+00
# 1163                                       5.726864e+11
# 1164                                       6.642367e+11
# 1165                                       7.302537e+11
#
#       Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_total_population_(%)  \
# 0                                          2.359690e+11
# 1                                          2.270450e+11
# 2                                          2.460002e+11
# 3                                          2.489774e+11
# 4                                          2.652209e+11
# ...                                                 ...
# 1161                                       5.490718e+11
# 1162                                      -3.500000e+00
# 1163                                       5.726864e+11
# 1164                                       6.642367e+11
# 1165                                       7.302537e+11
#
#       CPIA_social_protection_rating_(1=low_to_6=high)  ...  \
# 0                                        2.359690e+11  ...
# 1                                        2.270450e+11  ...
# 2                                        2.460002e+11  ...
# 3                                        2.489774e+11  ...
# 4                                        2.652209e+11  ...
# ...                                               ...  ...
# 1161                                     2.500000e+00  ...
# 1162                                     2.500000e+00  ...
# 1163                                     3.000000e+00  ...
# 1164                                     3.000000e+00  ...
# 1165                                     3.000000e+00  ...
#
#       Taxes_on_international_trade_(current_LCU)  Trade_(%_of_GDP)  \
# 0                                   2.359690e+11         45.424731
# 1                                   2.270450e+11         63.102906
# 2                                   2.460002e+11         64.036256
# 3                                   2.489774e+11         60.029466
# 4                                   2.652209e+11         57.388959
# ...                                          ...               ...
# 1161                                2.728550e+08         51.219025
# 1162                                2.950881e+08         50.029712
# 1163                                4.327694e+08         54.550270
# 1164                                6.642367e+11         52.687570
# 1165                                7.302537e+11         54.650561
#
#       Trade_in_services_(%_of_GDP)  \
# 0                        11.465418
# 1                        10.532252
# 2                        11.286972
# 3                        11.426541
# 4                        10.689284
# ...                            ...
# 1161                      8.080966
# 1162                      9.140222
# 1163                      4.469742
# 1164                      6.927164
# 1165                      5.118949
#
#       Unemployment,_total_(%_of_total_labor_force)_(modeled_ILO_estimate)  \
# 0                                              7.015272
# 1                                              6.939536
# 2                                              6.850376
# 3                                              6.803537
# 4                                              6.741241
# ...                                                 ...
# 1161                                           5.796000
# 1162                                           6.279000
# 1163                                           6.784000
# 1164                                           7.370000
# 1165                                           7.898000
#
#       Unemployment,_youth_total_(%_of_total_labor_force_ages_15-24)_(modeled_ILO_estimate)  \
# 0                                             13.076964
# 1                                             13.045450
# 2                                             13.043432
# 3                                             13.065178
# 4                                             13.075810
# ...                                                 ...
# 1161                                           8.781000
# 1162                                           9.670000
# 1163                                          10.592000
# 1164                                          11.616000
# 1165                                          12.700000
#
#       Urban_population  Urban_population_(%_of_total_population)  \
# 0          111533909.0                                 28.489868
# 1          115551653.0                                 28.772780
# 2          119775502.0                                 29.071591
# 3          124227507.0                                 29.386190
# 4          128833965.0                                 29.698419
# ...                ...                                       ...
# 1161         4667645.0                                 32.296000
# 1162         4755312.0                                 32.237000
# 1163         4848158.0                                 32.209000
# 1164         4945719.0                                 32.210000
# 1165         5052214.0                                 32.242000
#
#       Urban_population_growth_(annual_%)  \
# 0                               3.601474
# 1                               3.602262
# 2                               3.655377
# 3                               3.716958
# 4                               3.708082
# ...                                  ...
# 1161                            1.806610
# 1162                            1.860765
# 1163                            1.933653
# 1164                            1.992351
# 1165                            2.130421
#
#       Vulnerable_employment,_total_(%_of_total_employment)_(modeled_ILO_estimate)  \
# 0                                          7.342112e+01
# 1                                          7.355380e+01
# 2                                          7.358839e+01
# 3                                          7.372529e+01
# 4                                          7.395080e+01
# ...                                                 ...
# 1161                                       6.650000e+01
# 1162                                       6.672000e+01
# 1163                                       6.691000e+01
# 1164                                       6.835000e+01
# 1165                                       7.302537e+11
#
#       Wage_and_salaried_workers,_total_(%_of_total_employment)_(modeled_ILO_estimate)
# 0                                          2.293968e+01
# 1                                          2.287148e+01
# 2                                          2.286694e+01
# 3                                          2.259017e+01
# 4                                          2.247317e+01
# ...                                                 ...
# 1161                                       3.300000e+01
# 1162                                       3.281000e+01
# 1163                                       3.265000e+01
# 1164                                       3.125000e+01
# 1165                                       7.302537e+11
#
# [1166 rows x 106 columns]>

# %%
print(df.columns)
# Out:
# Index(['Country_Name', 'Year', 'Access_to_electricity_(%_of_population)',
#        'Adjusted_net_enrollment_rate,_primary_(%_of_primary_school_age_children)',
#        'Adjusted_net_national_income_(constant_2015_US$)',
#        'Adjusted_net_national_income_per_capita_(annual_%_growth)',
#        'Adjusted_net_national_income_per_capita_(constant_2015_US$)',
#        'Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_bottom_40%_of_population_(%)',
#        'Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_total_population_(%)',
#        'CPIA_social_protection_rating_(1=low_to_6=high)',
#        ...
#        'Taxes_on_international_trade_(current_LCU)', 'Trade_(%_of_GDP)',
#        'Trade_in_services_(%_of_GDP)',
#        'Unemployment,_total_(%_of_total_labor_force)_(modeled_ILO_estimate)',
#        'Unemployment,_youth_total_(%_of_total_labor_force_ages_15-24)_(modeled_ILO_estimate)',
#        'Urban_population', 'Urban_population_(%_of_total_population)',
#        'Urban_population_growth_(annual_%)',
#        'Vulnerable_employment,_total_(%_of_total_employment)_(modeled_ILO_estimate)',
#        'Wage_and_salaried_workers,_total_(%_of_total_employment)_(modeled_ILO_estimate)'],
#       dtype='object', length=106)

# %%
#One hot encoding 

import pandas as pd

# Read the CSV file into a pandas dataframe
df = pd.read_csv('EDA_dataset.csv')

# Select the categorical column to one-hot encode
cat_col = 'Country_Name'

# Perform one-hot encoding on the selected column using get_dummies()
one_hot_encoded = pd.get_dummies(df[cat_col], prefix=cat_col)

# Add the one-hot encoded columns to the original dataframe
df = pd.concat([df, one_hot_encoded], axis=1)

# Drop the original categorical column
df.drop(cat_col, axis=1, inplace=True)

# Print the encoded dataframe
print(df.head())
# Out:
#    Year  Access_to_electricity_(%_of_population)  \
# 0  1999                             2.359690e+11
# 1  2000                             1.995793e+01
# 2  2001                             1.998622e+01
# 3  2002                             2.160150e+01
# 4  2003                             2.254831e+01
#
#    Adjusted_net_enrollment_rate,_primary_(%_of_primary_school_age_children)  \
# 0                                       2.359690e+11
# 1                                       2.270450e+11
# 2                                       2.460002e+11
# 3                                       2.489774e+11
# 4                                       2.652209e+11
#
#    Adjusted_net_national_income_(constant_2015_US$)  \
# 0                                      2.359690e+11
# 1                                      2.270450e+11
# 2                                      2.460002e+11
# 3                                      3.991570e+11
# 4                                      4.191230e+11
#
#    Adjusted_net_national_income_per_capita_(annual_%_growth)  \
# 0                                       2.359690e+11
# 1                                       2.270450e+11
# 2                                       2.460002e+11
# 3                                       2.489774e+11
# 4                                       2.323504e+00
#
#    Adjusted_net_national_income_per_capita_(constant_2015_US$)  \
# 0                                       2.359690e+11
# 1                                       2.270450e+11
# 2                                       2.460002e+11
# 3                                       9.442113e+02
# 4                                       9.661501e+02
#
#    Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_bottom_40%_of_population_(%)  \
# 0                                       2.359690e+11
# 1                                       2.270450e+11
# 2                                       2.460002e+11
# 3                                       2.489774e+11
# 4                                       2.652209e+11
#
#    Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_total_population_(%)  \
# 0                                       2.359690e+11
# 1                                       2.270450e+11
# 2                                       2.460002e+11
# 3                                       2.489774e+11
# 4                                       2.652209e+11
#
#    CPIA_social_protection_rating_(1=low_to_6=high)  \
# 0                                     2.359690e+11
# 1                                     2.270450e+11
# 2                                     2.460002e+11
# 3                                     2.489774e+11
# 4                                     2.652209e+11
#
#    CPIA_trade_rating_(1=low_to_6=high)  ...  Country_Name_Sub-Saharan Africa  \
# 0                         2.359690e+11  ...                            False
# 1                         2.270450e+11  ...                            False
# 2                         2.460002e+11  ...                            False
# 3                         2.489774e+11  ...                            False
# 4                         2.652209e+11  ...                            False
#
#    Country_Name_Sub-Saharan Africa (IDA & IBRD countries)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Country_Name_Sub-Saharan Africa (excluding high income)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Country_Name_Sudan  Country_Name_Tanzania  Country_Name_Togo  \
# 0               False                  False              False
# 1               False                  False              False
# 2               False                  False              False
# 3               False                  False              False
# 4               False                  False              False
#
#    Country_Name_Uganda  Country_Name_World  Country_Name_Zambia  \
# 0                False               False                False
# 1                False               False                False
# 2                False               False                False
# 3                False               False                False
# 4                False               False                False
#
#    Country_Name_Zimbabwe
# 0                  False
# 1                  False
# 2                  False
# 3                  False
# 4                  False
#
# [5 rows x 158 columns]

# %%
df.to_csv('ANN_df.csv', index=False)

# %%
# Load the data into a pandas dataframe
data = pd.read_csv('ANN_df.csv')

# Print the list of column names
print(data.columns)
# Out:
# Index(['Year', 'Access_to_electricity_(%_of_population)',
#        'Adjusted_net_enrollment_rate,_primary_(%_of_primary_school_age_children)',
#        'Adjusted_net_national_income_(constant_2015_US$)',
#        'Adjusted_net_national_income_per_capita_(annual_%_growth)',
#        'Adjusted_net_national_income_per_capita_(constant_2015_US$)',
#        'Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_bottom_40%_of_population_(%)',
#        'Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_total_population_(%)',
#        'CPIA_social_protection_rating_(1=low_to_6=high)',
#        'CPIA_trade_rating_(1=low_to_6=high)',
#        ...
#        'Country_Name_Sub-Saharan Africa',
#        'Country_Name_Sub-Saharan Africa (IDA & IBRD countries)',
#        'Country_Name_Sub-Saharan Africa (excluding high income)',
#        'Country_Name_Sudan', 'Country_Name_Tanzania', 'Country_Name_Togo',
#        'Country_Name_Uganda', 'Country_Name_World', 'Country_Name_Zambia',
#        'Country_Name_Zimbabwe'],
#       dtype='object', length=158)

# %%
#ANN Test 1 - 90% Training / 10% Test Split

# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.1, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']

# %%
data.sample()
# Out:
#       Year  Access_to_electricity_(%_of_population)  \
# 1094  2015                                     18.5
#
#       Adjusted_net_enrollment_rate,_primary_(%_of_primary_school_age_children)  \
# 1094                                       4.907217e+11
#
#       Adjusted_net_national_income_(constant_2015_US$)  \
# 1094                                      2.460439e+10
#
#       Adjusted_net_national_income_per_capita_(annual_%_growth)  \
# 1094                                           1.454119
#
#       Adjusted_net_national_income_per_capita_(constant_2015_US$)  \
# 1094                                         656.513578
#
#       Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_bottom_40%_of_population_(%)  \
# 1094                                       4.907217e+11
#
#       Annualized_average_growth_rate_in_per_capita_real_survey_mean_consumption_or_income,_total_population_(%)  \
# 1094                                       4.907217e+11
#
#       CPIA_social_protection_rating_(1=low_to_6=high)  \
# 1094                                              3.5
#
#       CPIA_trade_rating_(1=low_to_6=high)  ...  \
# 1094                                  4.5  ...
#
#       Country_Name_Sub-Saharan Africa  \
# 1094                            False
#
#       Country_Name_Sub-Saharan Africa (IDA & IBRD countries)  \
# 1094                                              False
#
#       Country_Name_Sub-Saharan Africa (excluding high income)  \
# 1094                                              False
#
#       Country_Name_Sudan  Country_Name_Tanzania  Country_Name_Togo  \
# 1094               False                  False              False
#
#       Country_Name_Uganda  Country_Name_World  Country_Name_Zambia  \
# 1094                 True               False                False
#
#       Country_Name_Zimbabwe
# 1094                  False
#
# [1 rows x 158 columns]

# %%
# Adding Hyper-parameters to neural model

hidden_units1 = 40
hidden_units2 = 80
hidden_units3 = 120
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# Fit test data to model
y_pred = model.predict(x_test)  

# Calculate the R2 score 
r2 = r2_score(y_test, y_pred)
print("R2 Score:", r2)
# Out:
# 4/4 [==============================] - 0s 2ms/step
# R2 Score: -0.9181522922427754

# %%
# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.1
)
# Out:
# Epoch 1/10
# 15/15 [==============================] - 2s 28ms/step - loss: 46.6446 - mean_squared_logarithmic_error: 46.1603 - val_loss: 12.4112 - val_mean_squared_logarithmic_error: 12.2012
# Epoch 2/10
# 15/15 [==============================] - 0s 7ms/step - loss: 18.0186 - mean_squared_logarithmic_error: 17.9663 - val_loss: 10.2153 - val_mean_squared_logarithmic_error: 10.0043
# Epoch 3/10
# 15/15 [==============================] - 0s 7ms/step - loss: 16.5431 - mean_squared_logarithmic_error: 16.4942 - val_loss: 9.7900 - val_mean_squared_logarithmic_error: 9.5718
# Epoch 4/10
# 15/15 [==============================] - 0s 7ms/step - loss: 15.5984 - mean_squared_logarithmic_error: 15.4541 - val_loss: 9.0837 - val_mean_squared_logarithmic_error: 8.8613
# Epoch 5/10
# 15/15 [==============================] - 0s 6ms/step - loss: 14.7095 - mean_squared_logarithmic_error: 14.7708 - val_loss: 8.5496 - val_mean_squared_logarithmic_error: 8.3284
# Epoch 6/10
# 15/15 [==============================] - 0s 6ms/step - loss: 13.9784 - mean_squared_logarithmic_error: 14.0296 - val_loss: 8.1776 - val_mean_squared_logarithmic_error: 7.9620
# Epoch 7/10
# 15/15 [==============================] - 0s 6ms/step - loss: 13.4647 - mean_squared_logarithmic_error: 13.8560 - val_loss: 7.8604 - val_mean_squared_logarithmic_error: 7.6536
# Epoch 8/10
# 15/15 [==============================] - 0s 6ms/step - loss: 12.9476 - mean_squared_logarithmic_error: 13.0723 - val_loss: 7.5854 - val_mean_squared_logarithmic_error: 7.3847
# Epoch 9/10
# 15/15 [==============================] - 0s 6ms/step - loss: 12.5745 - mean_squared_logarithmic_error: 12.6321 - val_loss: 7.3403 - val_mean_squared_logarithmic_error: 7.1386
# Epoch 10/10
# 15/15 [==============================] - 0s 7ms/step - loss: 12.2269 - mean_squared_logarithmic_error: 12.1183 - val_loss: 7.1546 - val_mean_squared_logarithmic_error: 6.9664

# %%
# plot training and validation loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Mean Squared Logarithmic Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
x_test['prediction'] = model.predict(x_test_scaled)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
# Create a scatter plot of true vs predicted values
plt.scatter(y_test, x_test['prediction'], color='red')
plt.title('True vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.show()

# %%
# ANN Test 1 - RMSE Score 

from sklearn.metrics import r2_score, mean_squared_error
import numpy as np

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.1)

# Make predictions for the test set
y_pred = model.predict(x_test)


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 15/15 [==============================] - 0s 7ms/step - loss: 19.7713 - mean_squared_logarithmic_error: 19.5849 - val_loss: 11.4138 - val_mean_squared_logarithmic_error: 11.1283
# Epoch 2/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.6300 - mean_squared_logarithmic_error: 19.5875 - val_loss: 11.3800 - val_mean_squared_logarithmic_error: 11.0966
# Epoch 3/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.5115 - mean_squared_logarithmic_error: 19.5781 - val_loss: 11.3569 - val_mean_squared_logarithmic_error: 11.0753
# Epoch 4/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.4781 - mean_squared_logarithmic_error: 19.5276 - val_loss: 11.3416 - val_mean_squared_logarithmic_error: 11.0618
# Epoch 5/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.5481 - mean_squared_logarithmic_error: 19.4920 - val_loss: 11.3311 - val_mean_squared_logarithmic_error: 11.0530
# Epoch 6/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.4737 - mean_squared_logarithmic_error: 19.4073 - val_loss: 11.3257 - val_mean_squared_logarithmic_error: 11.0491
# Epoch 7/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.4340 - mean_squared_logarithmic_error: 19.3892 - val_loss: 11.3236 - val_mean_squared_logarithmic_error: 11.0485
# Epoch 8/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.4117 - mean_squared_logarithmic_error: 19.3581 - val_loss: 11.3227 - val_mean_squared_logarithmic_error: 11.0487
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.3507 - mean_squared_logarithmic_error: 19.2967 - val_loss: 11.3253 - val_mean_squared_logarithmic_error: 11.0527
# Epoch 10/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.3404 - mean_squared_logarithmic_error: 19.0375 - val_loss: 11.3285 - val_mean_squared_logarithmic_error: 11.0570
# 4/4 [==============================] - 0s 668us/step
# RMSE: 60688176310.01

# %%
#MAE Score


from sklearn.metrics import r2_score, mean_absolute_error
import numpy as np

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.1)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))
# Out:
# Epoch 1/10
# 15/15 [==============================] - 0s 7ms/step - loss: 19.3429 - mean_squared_logarithmic_error: 19.1742 - val_loss: 11.3323 - val_mean_squared_logarithmic_error: 11.0619
# Epoch 2/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.3214 - mean_squared_logarithmic_error: 19.2720 - val_loss: 11.3366 - val_mean_squared_logarithmic_error: 11.0671
# Epoch 3/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.3192 - mean_squared_logarithmic_error: 19.4214 - val_loss: 11.3413 - val_mean_squared_logarithmic_error: 11.0727
# Epoch 4/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.2063 - mean_squared_logarithmic_error: 19.4059 - val_loss: 11.3476 - val_mean_squared_logarithmic_error: 11.0799
# Epoch 5/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.2027 - mean_squared_logarithmic_error: 19.0435 - val_loss: 11.3531 - val_mean_squared_logarithmic_error: 11.0862
# Epoch 6/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.3153 - mean_squared_logarithmic_error: 19.1326 - val_loss: 11.3576 - val_mean_squared_logarithmic_error: 11.0914
# Epoch 7/10
# 15/15 [==============================] - 0s 2ms/step - loss: 19.2406 - mean_squared_logarithmic_error: 19.5594 - val_loss: 11.3607 - val_mean_squared_logarithmic_error: 11.0951
# Epoch 8/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.2080 - mean_squared_logarithmic_error: 19.0354 - val_loss: 11.3694 - val_mean_squared_logarithmic_error: 11.1046
# Epoch 9/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.2257 - mean_squared_logarithmic_error: 19.1802 - val_loss: 11.3725 - val_mean_squared_logarithmic_error: 11.1083
# Epoch 10/10
# 15/15 [==============================] - 0s 3ms/step - loss: 19.1706 - mean_squared_logarithmic_error: 19.2453 - val_loss: 11.3748 - val_mean_squared_logarithmic_error: 11.1111
# 4/4 [==============================] - 0s 1ms/step
# MAE: 10887261453.45

# %%
def plot_history(history, key):
  plt.plot(history.history[key])
  plt.plot(history.history['val_'+key])
  plt.xlabel("Epochs")
  plt.ylabel(key)
  plt.legend([key, 'val_'+key])
  plt.show()
# Plot the history
plot_history(history, 'mean_squared_logarithmic_error')

# %%
import matplotlib.pyplot as plt

# plot training and validation loss over epochs
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Mean Squared Logarithmic Error')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
x_test['prediction'] = model.predict(x_test_scaled)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
# Create a scatter plot of true vs predicted values
plt.scatter(y_test, x_test['prediction'], color='red')
plt.title('True vs Predicted Values')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'k--')
plt.show()

# %%
#ANN Test 1 - 80% Training / 20% Test Split

# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']

# %%
# Pre-processing of data set by scaling with Standard Scaler

def scale_datasets(x_train, x_test):

  
  standard_scaler = StandardScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
# Adding Hyper-parameters to neural model

hidden_units1 = 40
hidden_units2 = 80
hidden_units3 = 120
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 12/12 [==============================] - 1s 11ms/step - loss: 53.5997 - mean_squared_logarithmic_error: 52.4409 - val_loss: 16.0756 - val_mean_squared_logarithmic_error: 15.9425
# Epoch 2/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.3524 - mean_squared_logarithmic_error: 20.0102 - val_loss: 11.6548 - val_mean_squared_logarithmic_error: 11.5276
# Epoch 3/10
# 12/12 [==============================] - 0s 3ms/step - loss: 17.6480 - mean_squared_logarithmic_error: 17.4001 - val_loss: 11.3679 - val_mean_squared_logarithmic_error: 11.2453
# Epoch 4/10
# 12/12 [==============================] - 0s 3ms/step - loss: 16.8362 - mean_squared_logarithmic_error: 17.0107 - val_loss: 10.9461 - val_mean_squared_logarithmic_error: 10.8291
# Epoch 5/10
# 12/12 [==============================] - 0s 3ms/step - loss: 16.1966 - mean_squared_logarithmic_error: 16.3668 - val_loss: 10.2963 - val_mean_squared_logarithmic_error: 10.1858
# Epoch 6/10
# 12/12 [==============================] - 0s 3ms/step - loss: 15.3781 - mean_squared_logarithmic_error: 15.1508 - val_loss: 9.6833 - val_mean_squared_logarithmic_error: 9.5788
# Epoch 7/10
# 12/12 [==============================] - 0s 3ms/step - loss: 14.7832 - mean_squared_logarithmic_error: 14.5508 - val_loss: 9.2336 - val_mean_squared_logarithmic_error: 9.1337
# Epoch 8/10
# 12/12 [==============================] - 0s 3ms/step - loss: 14.2618 - mean_squared_logarithmic_error: 14.5915 - val_loss: 8.8650 - val_mean_squared_logarithmic_error: 8.7697
# Epoch 9/10
# 12/12 [==============================] - 0s 3ms/step - loss: 13.9052 - mean_squared_logarithmic_error: 13.7037 - val_loss: 8.5551 - val_mean_squared_logarithmic_error: 8.4645
# Epoch 10/10
# 12/12 [==============================] - 0s 3ms/step - loss: 13.4696 - mean_squared_logarithmic_error: 13.7822 - val_loss: 8.2918 - val_mean_squared_logarithmic_error: 8.2046

# %%
# ANN Test 1 - R2 Score 

from sklearn.metrics import r2_score

# Train the model
model.fit(x_train, y_train, epochs=10, batch_size=64, validation_split=0.2)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))



# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))



# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 12/12 [==============================] - 0s 9ms/step - loss: 20.8655 - mean_squared_logarithmic_error: 21.3515 - val_loss: 12.8675 - val_mean_squared_logarithmic_error: 12.7243
# Epoch 2/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.7317 - mean_squared_logarithmic_error: 20.4233 - val_loss: 12.7834 - val_mean_squared_logarithmic_error: 12.6405
# Epoch 3/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.6027 - mean_squared_logarithmic_error: 20.0174 - val_loss: 12.7163 - val_mean_squared_logarithmic_error: 12.5738
# Epoch 4/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.4452 - mean_squared_logarithmic_error: 21.5020 - val_loss: 12.6707 - val_mean_squared_logarithmic_error: 12.5285
# Epoch 5/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.3607 - mean_squared_logarithmic_error: 19.7761 - val_loss: 12.6285 - val_mean_squared_logarithmic_error: 12.4866
# Epoch 6/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.2480 - mean_squared_logarithmic_error: 20.7653 - val_loss: 12.5991 - val_mean_squared_logarithmic_error: 12.4574
# Epoch 7/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.1727 - mean_squared_logarithmic_error: 20.1174 - val_loss: 12.5735 - val_mean_squared_logarithmic_error: 12.4320
# Epoch 8/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.1196 - mean_squared_logarithmic_error: 20.6141 - val_loss: 12.5567 - val_mean_squared_logarithmic_error: 12.4155
# Epoch 9/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.0958 - mean_squared_logarithmic_error: 20.3248 - val_loss: 12.5433 - val_mean_squared_logarithmic_error: 12.4023
# Epoch 10/10
# 12/12 [==============================] - 0s 3ms/step - loss: 20.0878 - mean_squared_logarithmic_error: 19.7953 - val_loss: 12.5332 - val_mean_squared_logarithmic_error: 12.3923
# 8/8 [==============================] - 0s 715us/step
# R^2 score: -0.04
# MAE: 12511631393.40
# RMSE: 67340242098.80

# %%
#ANN Test 1 - 70% Training / 30% Test Split

# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']

# Pre-processing of data set by scaling with Standard Scaler

def scale_datasets(x_train, x_test):

  
  standard_scaler = StandardScaler()
  x_train_scaled = pd.DataFrame(
      standard_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      standard_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled
x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# Adding Hyper-parameters to neural model

hidden_units1 = 40
hidden_units2 = 80
hidden_units3 = 120
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.3
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))



# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))



# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 11/11 [==============================] - 1s 12ms/step - loss: 14.9404 - mean_squared_logarithmic_error: 15.3893 - val_loss: 9.8988 - val_mean_squared_logarithmic_error: 8.7392
# Epoch 2/10
# 11/11 [==============================] - 0s 3ms/step - loss: 12.8343 - mean_squared_logarithmic_error: 13.3444 - val_loss: 9.0950 - val_mean_squared_logarithmic_error: 8.0205
# Epoch 3/10
# 11/11 [==============================] - 0s 3ms/step - loss: 11.7205 - mean_squared_logarithmic_error: 10.9944 - val_loss: 8.4281 - val_mean_squared_logarithmic_error: 7.4244
# Epoch 4/10
# 11/11 [==============================] - 0s 3ms/step - loss: 11.0226 - mean_squared_logarithmic_error: 10.4892 - val_loss: 7.9784 - val_mean_squared_logarithmic_error: 7.0406
# Epoch 5/10
# 11/11 [==============================] - 0s 3ms/step - loss: 10.5341 - mean_squared_logarithmic_error: 9.8352 - val_loss: 7.6325 - val_mean_squared_logarithmic_error: 6.7322
# Epoch 6/10
# 11/11 [==============================] - 0s 3ms/step - loss: 10.1395 - mean_squared_logarithmic_error: 9.4027 - val_loss: 7.3242 - val_mean_squared_logarithmic_error: 6.4671
# Epoch 7/10
# 11/11 [==============================] - 0s 3ms/step - loss: 9.7644 - mean_squared_logarithmic_error: 9.0533 - val_loss: 7.0644 - val_mean_squared_logarithmic_error: 6.2445
# Epoch 8/10
# 11/11 [==============================] - 0s 3ms/step - loss: 9.3725 - mean_squared_logarithmic_error: 9.6473 - val_loss: 6.7507 - val_mean_squared_logarithmic_error: 5.9701
# Epoch 9/10
# 11/11 [==============================] - 0s 3ms/step - loss: 9.0608 - mean_squared_logarithmic_error: 8.4041 - val_loss: 6.4760 - val_mean_squared_logarithmic_error: 5.7249
# Epoch 10/10
# 11/11 [==============================] - 0s 3ms/step - loss: 8.7165 - mean_squared_logarithmic_error: 8.0806 - val_loss: 6.2342 - val_mean_squared_logarithmic_error: 5.5110
# 8/8 [==============================] - 0s 858us/step
# R^2 score: -76993127867.81
# MAE: 3719428958692130.50
# RMSE: 18359978121864628.00

# %%
#ANN Tests using the Robust Scaler - 10% Testing Size
from sklearn.preprocessing import RobustScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.1, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']

# %%
# Pre-processing of data set by scaling with Robust Scaler



def scale_datasets(x_train, x_test):
    scaler = RobustScaler()
    x_train_scaled = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
    x_test_scaled = pd.DataFrame(scaler.transform(x_test), columns = x_test.columns)
    return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)

# %%
# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()

# %%
# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=64,
    validation_split=0.1
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))



# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))



# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 15/15 [==============================] - 1s 11ms/step - loss: 85.5997 - mean_squared_logarithmic_error: 85.6814 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 2/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 85.1785 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 3/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.9663 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 4/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.9131 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 5/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.7210 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 6/10
# 15/15 [==============================] - 0s 5ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.7179 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 7/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.9050 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 8/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.9519 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 9/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 84.9506 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# Epoch 10/10
# 15/15 [==============================] - 0s 4ms/step - loss: 84.8299 - mean_squared_logarithmic_error: 85.1881 - val_loss: 71.2352 - val_mean_squared_logarithmic_error: 70.8439
# 4/4 [==============================] - 0s 1ms/step
# R^2 score: -690775151.89
# MAE: 763419217669763.88
# RMSE: 1569166487302331.75

# %%
#ANN Tests using the Robust Scaler - 20% Testing Size
from sklearn.preprocessing import RobustScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']


# Pre-processing of data set by scaling with Robust Scaler


def scale_datasets(x_train, x_test):
    scaler = RobustScaler()
    x_train_scaled = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
    x_test_scaled = pd.DataFrame(scaler.transform(x_test), columns = x_test.columns)
    return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)


# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()


# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=100,
    validation_split=0.2
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 1s 19ms/step - loss: 87.0683 - mean_squared_logarithmic_error: 84.8726 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 2/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 86.3032 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 3/10
# 8/8 [==============================] - 0s 6ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 87.6688 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 4/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 86.3900 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 5/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 87.3599 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 6/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 84.2173 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 7/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 84.4065 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 8/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 85.3080 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 9/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 85.1614 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# Epoch 10/10
# 8/8 [==============================] - 0s 7ms/step - loss: 86.7278 - mean_squared_logarithmic_error: 89.2257 - val_loss: 72.3138 - val_mean_squared_logarithmic_error: 72.0482
# 8/8 [==============================] - 0s 858us/step
# R^2 score: -14419117.77
# MAE: 117971719477525.53
# RMSE: 251255476887420.28

# %%
#ANN Tests using the Robust Scaler - 30% Testing Size
from sklearn.preprocessing import RobustScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']


# Pre-processing of data set by scaling with Robust Scaler


def scale_datasets(x_train, x_test):
    scaler = RobustScaler()
    x_train_scaled = pd.DataFrame(scaler.fit_transform(x_train), columns=x_train.columns)
    x_test_scaled = pd.DataFrame(scaler.transform(x_test), columns = x_test.columns)
    return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)


# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()


# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=100,
    validation_split=0.3
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 25ms/step - loss: 94.3099 - mean_squared_logarithmic_error: 94.0087 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 2/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 87.8917 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 3/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 86.7131 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 4/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 87.1223 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 5/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 88.7208 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 6/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 87.5147 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 7/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 88.4008 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 8/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 87.0103 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 9/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 86.7111 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# Epoch 10/10
# 6/6 [==============================] - 0s 8ms/step - loss: 87.3762 - mean_squared_logarithmic_error: 87.8738 - val_loss: 77.3548 - val_mean_squared_logarithmic_error: 75.7072
# 11/11 [==============================] - 0s 901us/step
# R^2 score: -429453595.56
# MAE: 764416231915667.50
# RMSE: 1537236454207016.75

# %%
#ANN Tests using the MinMax Scaler - 10% Testing Size
from sklearn.preprocessing import MinMaxScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.1, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']


# Pre-processing of data set by scaling with Min/Max Scaler


def scale_datasets(x_train, x_test):
  
  minmax_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      minmax_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      minmax_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)


# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()


# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=100,
    validation_split=0.1
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 10/10 [==============================] - 1s 15ms/step - loss: 33.9760 - mean_squared_logarithmic_error: 33.0164 - val_loss: 11.4851 - val_mean_squared_logarithmic_error: 7.4166
# Epoch 2/10
# 10/10 [==============================] - 0s 5ms/step - loss: 18.7953 - mean_squared_logarithmic_error: 18.8028 - val_loss: 13.4443 - val_mean_squared_logarithmic_error: 10.3095
# Epoch 3/10
# 10/10 [==============================] - 0s 5ms/step - loss: 19.2635 - mean_squared_logarithmic_error: 19.8552 - val_loss: 12.6359 - val_mean_squared_logarithmic_error: 9.3082
# Epoch 4/10
# 10/10 [==============================] - 0s 5ms/step - loss: 18.2710 - mean_squared_logarithmic_error: 18.9404 - val_loss: 11.2791 - val_mean_squared_logarithmic_error: 7.4935
# Epoch 5/10
# 10/10 [==============================] - 0s 5ms/step - loss: 17.3421 - mean_squared_logarithmic_error: 16.8410 - val_loss: 10.3437 - val_mean_squared_logarithmic_error: 6.1614
# Epoch 6/10
# 10/10 [==============================] - 0s 5ms/step - loss: 16.7154 - mean_squared_logarithmic_error: 15.8398 - val_loss: 9.7424 - val_mean_squared_logarithmic_error: 5.5043
# Epoch 7/10
# 10/10 [==============================] - 0s 5ms/step - loss: 15.9195 - mean_squared_logarithmic_error: 16.5711 - val_loss: 9.1849 - val_mean_squared_logarithmic_error: 5.2470
# Epoch 8/10
# 10/10 [==============================] - 0s 5ms/step - loss: 15.1493 - mean_squared_logarithmic_error: 15.0728 - val_loss: 8.5760 - val_mean_squared_logarithmic_error: 4.7789
# Epoch 9/10
# 10/10 [==============================] - 0s 6ms/step - loss: 14.3493 - mean_squared_logarithmic_error: 14.9666 - val_loss: 8.1982 - val_mean_squared_logarithmic_error: 4.5758
# Epoch 10/10
# 10/10 [==============================] - 0s 5ms/step - loss: 13.7196 - mean_squared_logarithmic_error: 13.9391 - val_loss: 7.7428 - val_mean_squared_logarithmic_error: 4.2249
# 4/4 [==============================] - 0s 1ms/step
# R^2 score: -2137957674817.61
# MAE: 15663067098302930.00
# RMSE: 87297181485537792.00

# %%
#ANN Tests using the MinMax Scaler - 20% Testing Size
from sklearn.preprocessing import MinMaxScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']


# Pre-processing of data set by scaling with Min/Max Scaler


def scale_datasets(x_train, x_test):
  
  minmax_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      minmax_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      minmax_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)


# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()


# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=100,
    validation_split=0.2
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 8/8 [==============================] - 1s 18ms/step - loss: 37.8389 - mean_squared_logarithmic_error: 37.4595 - val_loss: 12.3310 - val_mean_squared_logarithmic_error: 12.1285
# Epoch 2/10
# 8/8 [==============================] - 0s 6ms/step - loss: 19.3673 - mean_squared_logarithmic_error: 18.8060 - val_loss: 14.5608 - val_mean_squared_logarithmic_error: 14.3743
# Epoch 3/10
# 8/8 [==============================] - 0s 6ms/step - loss: 20.3738 - mean_squared_logarithmic_error: 19.4173 - val_loss: 15.0151 - val_mean_squared_logarithmic_error: 14.8317
# Epoch 4/10
# 8/8 [==============================] - 0s 6ms/step - loss: 19.9830 - mean_squared_logarithmic_error: 19.3591 - val_loss: 13.8001 - val_mean_squared_logarithmic_error: 13.6148
# Epoch 5/10
# 8/8 [==============================] - 0s 6ms/step - loss: 18.9112 - mean_squared_logarithmic_error: 18.7278 - val_loss: 12.4997 - val_mean_squared_logarithmic_error: 12.3113
# Epoch 6/10
# 8/8 [==============================] - 0s 6ms/step - loss: 18.1896 - mean_squared_logarithmic_error: 18.9370 - val_loss: 11.7635 - val_mean_squared_logarithmic_error: 11.5737
# Epoch 7/10
# 8/8 [==============================] - 0s 7ms/step - loss: 17.8408 - mean_squared_logarithmic_error: 16.6926 - val_loss: 11.4047 - val_mean_squared_logarithmic_error: 11.2170
# Epoch 8/10
# 8/8 [==============================] - 0s 6ms/step - loss: 17.4850 - mean_squared_logarithmic_error: 17.2873 - val_loss: 11.0890 - val_mean_squared_logarithmic_error: 10.9055
# Epoch 9/10
# 8/8 [==============================] - 0s 6ms/step - loss: 16.9109 - mean_squared_logarithmic_error: 16.2836 - val_loss: 10.7063 - val_mean_squared_logarithmic_error: 10.5286
# Epoch 10/10
# 8/8 [==============================] - 0s 6ms/step - loss: 16.2486 - mean_squared_logarithmic_error: 16.5481 - val_loss: 10.1828 - val_mean_squared_logarithmic_error: 10.0132
# 8/8 [==============================] - 0s 858us/step
# R^2 score: -197278536946.33
# MAE: 6281308287436032.00
# RMSE: 29389087162754308.00

# %%
#ANN Tests using the MinMax Scaler - 30% Testing Size
from sklearn.preprocessing import MinMaxScaler


# Load data from CSV file
data = pd.read_csv('ANN_df.csv')

# Split data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.3, random_state=42)

# Separate features and target variable in training set
x_train = train_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_train = train_data['GDP_per_capita_(constant_2015_US$)']


# Separate features and target variable in testing set
x_test = test_data.drop('GDP_per_capita_(constant_2015_US$)', axis=1)
y_test = test_data['GDP_per_capita_(constant_2015_US$)']


# Pre-processing of data set by scaling with Min/Max Scaler


def scale_datasets(x_train, x_test):
  
  minmax_scaler = MinMaxScaler()
  x_train_scaled = pd.DataFrame(
      minmax_scaler.fit_transform(x_train),
      columns=x_train.columns
  )
  x_test_scaled = pd.DataFrame(
      minmax_scaler.transform(x_test),
      columns = x_test.columns
  )
  return x_train_scaled, x_test_scaled

x_train_scaled, x_test_scaled = scale_datasets(x_train, x_test)


# Adding Hyper-parameters to neural model

hidden_units1 = 150
hidden_units2 = 300
hidden_units3 = 450
learning_rate = 0.01
# Creating model using the Sequential in tensorflow
def build_model_using_sequential():
  model = Sequential([
    Dense(hidden_units1, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units2, kernel_initializer='normal', activation='relu'),
    Dropout(0.2),
    Dense(hidden_units3, kernel_initializer='normal', activation='relu'),
    Dense(1, kernel_initializer='normal', activation='linear')
  ])
  return model
# build the model
model = build_model_using_sequential()


# ANN Test 1 - MSLE Score 

# loss function
msle = MeanSquaredLogarithmicError()
model.compile(
    loss=msle, 
    optimizer=Adam(learning_rate=learning_rate), 
    metrics=[msle]
)
# train the model
history = model.fit(
    x_train_scaled.values, 
    y_train.values, 
    epochs=10, 
    batch_size=100,
    validation_split=0.3
)

# Make predictions for the test set
y_pred = model.predict(x_test)

# Calculate R^2 score
r2 = r2_score(y_test, y_pred)
print("R^2 score: {:.2f}".format(r2))


# Calculate MAE
mae = mean_absolute_error(y_test, y_pred)
print("MAE: {:.2f}".format(mae))


# Calculate RMSE
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
print("RMSE: {:.2f}".format(rmse))
# Out:
# Epoch 1/10
# 6/6 [==============================] - 1s 24ms/step - loss: 54.0019 - mean_squared_logarithmic_error: 53.2913 - val_loss: 17.5732 - val_mean_squared_logarithmic_error: 16.2941
# Epoch 2/10
# 6/6 [==============================] - 0s 7ms/step - loss: 20.2330 - mean_squared_logarithmic_error: 19.6054 - val_loss: 15.9100 - val_mean_squared_logarithmic_error: 14.8017
# Epoch 3/10
# 6/6 [==============================] - 0s 8ms/step - loss: 19.6791 - mean_squared_logarithmic_error: 19.5903 - val_loss: 17.5251 - val_mean_squared_logarithmic_error: 16.4711
# Epoch 4/10
# 6/6 [==============================] - 0s 7ms/step - loss: 20.4358 - mean_squared_logarithmic_error: 20.5161 - val_loss: 17.7343 - val_mean_squared_logarithmic_error: 16.6919
# Epoch 5/10
# 6/6 [==============================] - 0s 7ms/step - loss: 20.2130 - mean_squared_logarithmic_error: 20.6184 - val_loss: 16.9156 - val_mean_squared_logarithmic_error: 15.8621
# Epoch 6/10
# 6/6 [==============================] - 0s 8ms/step - loss: 19.4086 - mean_squared_logarithmic_error: 19.2880 - val_loss: 15.9344 - val_mean_squared_logarithmic_error: 14.8638
# Epoch 7/10
# 6/6 [==============================] - 0s 7ms/step - loss: 18.7099 - mean_squared_logarithmic_error: 18.7539 - val_loss: 15.0313 - val_mean_squared_logarithmic_error: 13.9382
# Epoch 8/10
# 6/6 [==============================] - 0s 7ms/step - loss: 18.3032 - mean_squared_logarithmic_error: 18.7792 - val_loss: 14.5296 - val_mean_squared_logarithmic_error: 13.4207
# Epoch 9/10
# 6/6 [==============================] - 0s 8ms/step - loss: 18.0396 - mean_squared_logarithmic_error: 17.8840 - val_loss: 14.2851 - val_mean_squared_logarithmic_error: 13.1860
# Epoch 10/10
# 6/6 [==============================] - 0s 7ms/step - loss: 17.7488 - mean_squared_logarithmic_error: 17.9999 - val_loss: 14.0366 - val_mean_squared_logarithmic_error: 12.9571
# 11/11 [==============================] - 0s 801us/step
# R^2 score: -22720639820.89
# MAE: 3752000962873208.00
# RMSE: 11181313679063984.00
